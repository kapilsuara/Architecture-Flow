# %% [markdown]
# # Feature selection
# ## Filter method
# #### Feature selection based on statistical test , irrespective of any machine learning model

# %% [markdown]
# ### Variance Threshold

# %%
# Dataset generate

from sklearn.
